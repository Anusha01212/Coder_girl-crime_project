# %% [markdown]
# 1) Hypothesis or Question
#
# 2) Store your data  in dataframe to check your hypothesis/question
#
# 3) 2-3 visuals per hypothesis/question,
#
# 4) Apply basic statistics
#
# 5) Create a presentation

# %% [markdown]
# Hypothesis:
# 1) There was a rise in Anti-Asian hate crimes during the COVID-19 pandemic.
#    (pull data from 2018; pull data from 2019 - 2020)
#
# 2) There was a rise in Anti-Muslim hate crimes post 9/11 (pull data from 2000; pull data from 2002)
#
# 3) What is the highest count of hate crime for 2020? How has it changed over the last 3 years?

# %%
import crime_api
from crime_api import crime_api_key

# %%
print(crime_api_key)
# Out:
# cgtxxbzQkX2MoRb9D5Neb3M9gzrpShGUEvfebDhG

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint


#modules for statistics
import math
import statistics
from scipy import stats

# %%
#Endpoint Name: 'National level Hate Crime Count Endpoint'
#Endpoint: /api/hatecrime/national/{variable}
#Parameters: BIAS_INCIDENT


base_url_N = "https://api.usa.gov/crime/fbi/sapi/api/hatecrime/national/BIAS_INCIDENT?API_KEY=" + crime_api_key
req_crime_N = requests.get(base_url_N)


#create a json output of the data
json_crime_data_N = req_crime_N.json()
print(json_crime_data_N)
# Out:
# {'ui_type': 'basic_table', 'noun': 'bias', 'category': 'Incident Bias characteristics', 'title': 'Bias (Anti-)', 'short_title': 'Bias', 'ui_restriction': None, 'keys': ['Anti-Other Race/Ethnicity/Ancestry', 'Multiple Bias', 'Anti-Atheism/Agnosticism', 'Anti-Mormon', 'Anti-Other Christian', 'Anti-Male', 'Anti-Buddhist', 'Anti-Sikh', 'Anti-Multiple Races, Group', 'Anti-Native Hawaiian or Other Pacific Islander', 'Anti-Mental Disability', 'Anti-Arab', 'Anti-Heterosexual', 'Anti-Transgender', 'Anti-Asian', 'Anti-Multiple Religions, Group', 'Anti-Hispanic or Latino', 'Anti-American Indian or Alaska Native', 'Anti-Bisexual', 'Anti-Black or African American', 'Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)', 'Anti-Jehovahs Witness', 'Anti-Protestant', 'Anti-White', 'Anti-Lesbian (Female)', 'Anti-Physical Disability', 'Anti-Islamic (Muslim)', 'Anti-Hindu', 'Anti-Other Religion', 'Anti-Gay (Male)', 'Anti-Eastern Orthodox (Russian, Greek, Other)', 'Anti-Jewish', 'Anti-Gender Non-Conforming', 'Anti-Female', 'Anti-Catholic'], 'data': [{'value': 313, 'data_year': 2010, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 269, 'data_year': 2018, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 417, 'data_year': 2006, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 317, 'data_year': 2000, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 589, 'data_year': 2003, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 225, 'data_year': 1993, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 340, 'data_year': 1999, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 298, 'data_year': 2020, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 434, 'data_year': 2005, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 337, 'data_year': 1996, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 337, 'data_year': 2013, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 294, 'data_year': 2009, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 498, 'data_year': 2004, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 413, 'data_year': 2007, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 254, 'data_year': 1998, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 243, 'data_year': 1995, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 312, 'data_year': 2012, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 298, 'data_year': 2019, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 318, 'data_year': 2011, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 546, 'data_year': 2002, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 1251, 'data_year': 2001, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 346, 'data_year': 2014, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 312, 'data_year': 1997, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 132, 'data_year': 1991, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 280, 'data_year': 2017, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 241, 'data_year': 1992, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 351, 'data_year': 2008, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 258, 'data_year': 2015, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 226, 'data_year': 2016, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 251, 'data_year': 1994, 'month_num': 0, 'key': 'Anti-Other Race/Ethnicity/Ancestry'}, {'value': 4, 'data_year': 2010, 'month_num': 0, 'key': 'Multiple Bias ...

# %%
sorted_crime_df_N = df_N.sort_values("data_year", ascending=False)
sorted_crime_df_N.reset_index(drop=True, inplace=True)
sorted_crime_df_N
# Out:
#       value  data_year  month_num                         key
# 0        71       2020          0                   Anti-Arab
# 1       279       2020          0                  Anti-Asian
# 2        76       2020          0         Anti-Other Religion
# 3       211       2020          0  Anti-Multiple Races, Group
# 4        53       2020          0    Anti-Physical Disability
# ...     ...        ...        ...                         ...
# 1045      1       1991          0               Anti-Bisexual
# 1046      0       1991          0        Anti-Other Christian
# 1047      0       1991          0  Anti-Gender Non-Conforming
# 1048     86       1991          0  Anti-Multiple Races, Group
# 1049    269       1991          0                  Anti-Asian
#
# [1050 rows x 4 columns]

# %%
df_N = pd.DataFrame(json_crime_data_N['data'])
sorted_crime_df_N = df_N.sort_values("data_year", ascending=False)
#print(sorted_crime_df_N["data_year"].value_counts())

national_crime_2020_df = sorted_crime_df_N.head(35)
national_crime_2020_df.reset_index(drop=True, inplace=True)
national_crime_2020_df
# Out:
#     value  data_year  month_num  \
# 0      71       2020          0
# 1     279       2020          0
# 2      76       2020          0
# 3     211       2020          0
# 4      53       2020          0
# 5       9       2020          0
# 6      40       2020          0
# 7       8       2020          0
# 8      11       2020          0
# 9     683       2020          0
# 10    110       2020          0
# 11     53       2020          0
# 12     15       2020          0
# 13     96       2020          0
# 14     50       2020          0
# 15     15       2020          0
# 16    211       2020          0
# 17    869       2020          0
# 18     43       2020          0
# 19     50       2020          0
# 20      7       2020          0
# 21   2871       2020          0
# 22     17       2020          0
# 23    517       2020          0
# 24    213       2020          0
# 25     77       2020          0
# 26    673       2020          0
# 27    103       2020          0
# 28     30       2020          0
# 29    306       2020          0
# 30     73       2020          0
# 31     89       2020          0
# 32     25       2020          0
# 33    298       2020          0
# 34     11       2020          0
#
#                                                   key
# 0                                           Anti-Arab
# 1                                          Anti-Asian
# 2                                 Anti-Other Religion
# 3                          Anti-Multiple Races, Group
# 4                            Anti-Physical Disability
# 5                               Anti-Jehovahs Witness
# 6                      Anti-Multiple Religions, Group
# 7                            Anti-Atheism/Agnosticism
# 8                                          Anti-Hindu
# 9                                         Anti-Jewish
# 10                              Anti-Islamic (Muslim)
# 11                         Anti-Gender Non-Conforming
# 12                                      Anti-Buddhist
# 13              Anti-American Indian or Alaska Native
# 14                               Anti-Other Christian
# 15     Anti-Native Hawaiian or Other Pacific Islander
# 16                                      Multiple Bias
# 17                                         Anti-White
# 18      Anti-Eastern Orthodox (Russian, Greek, Other)
# 19                                        Anti-Female
# 20                                        Anti-Mormon
# 21                     Anti-Black or African American
# 22                                      Anti-Bisexual
# 23                            Anti-Hispanic or Latino
# 24                                   Anti-Transgender
# 25                             Anti-Mental Disability
# 26                                    Anti-Gay (Male)
# 27                              Anti-Lesbian (Female)
# 28                                    Anti-Protestant
# 29  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 30                                      Anti-Catholic
# 31                                          Anti-Sikh
# 32                                          Anti-Male
# 33                 Anti-Other Race/Ethnicity/Ancestry
# 34                                  Anti-Heterosexual

# %%
crimes = national_crime_2020_df['key']  #key column is extracted
crime_count = national_crime_2020_df['value'] #value column is extracted


fig, ax = plt.subplots(figsize =(10, 15)) #dimensions for graph size are given : 10:width, 15:height

#ax.barh() is used to make horizontal graphs. This function accepts multiple parameters. 
#Two of which are: left = the x coordinate(s) of the left sides of the bars('crime') &
#y= sequence of y coordinates of the bar('crime_count')

ax.barh(crimes, crime_count)  
 
#Each of the four sides (the border of the graph) from the list are removed/invisible 
#because the spines are set to false. 
for sides in ['top', 'bottom','left', 'right']:
    ax.spines[sides].set_visible(False)
 
#Here I have removed the ticks from both the x and y axis so that the values can show properly. 
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
#Here I have increased the spacing between each axes and its labels as I see fit.
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 25)
 
#the following function--grid()--allows me to customize how I want my gridlines to be. 
#b=true: means gird is on, color of gridlines set to blue, linestlyle is slash(-.) linewidth is .5 
#(I made it very narrow as I wanted the main focus to be the bar and the associated values next to it)
#finally, alpha is the level of transparency which by default is 1 but I wanted it to be more transparent. 
ax.grid(b = True, color ='blue', linestyle ='-.', linewidth = 0.5, alpha = 0.2)
 
 
#The for loop will iterate over each bar, putting a text ('value') beside it.
    #plt.text() allows you to put text at a certain location on the graph. 
    #The get_width() will pull the text(in this case the value) left or right.
    #It is the x position where you want the text to be.
    #I wanted to keep the text close to the bar so I left it as is(didn't have to add a number)
    #And get_y() [the y-position where you want the text to be] will pull the text up or down: 
    #+0.25 was the best option as it allowed the text to be printed in the center compared to if I didn't add 
    #anything to the y position. Last the s or str is the text that I want to input 
    #(in this case i.get_width() is referring to each value)
    #fontsize, fontweight and color are all text properties. 
for i in ax.patches:
    plt.text(i.get_width(), i.get_y()+0.25,
             i.get_width(), fontsize = 10, fontweight ='bold', color ='Red')
 
#Title is given.
ax.set_title('Hate Crime Data 2020',
             loc ='left', )
 
# Show Plot
plt.show()

# %%
#print(sorted_crime_df_N["data_year"].value_counts())

national_crime_2019_df = sorted_crime_df_N.iloc[35:70, ]
national_crime_2019_df
#national_crime_df.reset_index(drop=True, inplace=True)
#national_crime_df
# Out:
#     value  data_year  month_num  \
# 35    539       2019          0
# 36     64       2019          0
# 37     23       2019          0
# 38    180       2019          0
# 39     37       2019          0
# 40     94       2019          0
# 41      6       2019          0
# 42    643       2019          0
# 43     46       2019          0
# 44    131       2019          0
# 45    295       2019          0
# 46    963       2019          0
# 47    108       2019          0
# 48     27       2019          0
# 49     53       2019          0
# 50   1972       2019          0
# 51     11       2019          0
# 52     54       2019          0
# 53      4       2019          0
# 54     50       2019          0
# 55     16       2019          0
# 56    206       2019          0
# 57      5       2019          0
# 58     98       2019          0
# 59     21       2019          0
# 60     49       2019          0
# 61    745       2019          0
# 62     14       2019          0
# 63    161       2019          0
# 64     86       2019          0
# 65    152       2019          0
# 66    298       2019          0
# 67     37       2019          0
# 68      6       2019          0
# 69     93       2019          0
#
#                                                   key
# 35                            Anti-Hispanic or Latino
# 36                                      Anti-Catholic
# 37     Anti-Native Hawaiian or Other Pacific Islander
# 38                              Anti-Islamic (Muslim)
# 39                         Anti-Gender Non-Conforming
# 40              Anti-American Indian or Alaska Native
# 41                           Anti-Atheism/Agnosticism
# 42                                         Anti-White
# 43                           Anti-Physical Disability
# 44                         Anti-Multiple Races, Group
# 45  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 46                                        Anti-Jewish
# 47                              Anti-Lesbian (Female)
# 48                                      Anti-Bisexual
# 49                                        Anti-Female
# 50                     Anti-Black or African American
# 51                                        Anti-Mormon
# 52                                          Anti-Sikh
# 53                                      Anti-Buddhist
# 54      Anti-Eastern Orthodox (Russian, Greek, Other)
# 55                                  Anti-Heterosexual
# 56                                      Multiple Bias
# 57                                         Anti-Hindu
# 58                             Anti-Mental Disability
# 59                                    Anti-Protestant
# 60                               Anti-Other Christian
# 61                                    Anti-Gay (Male)
# 62                                          Anti-Male
# 63                                         Anti-Asian
# 64                                Anti-Other Religion
# 65                                   Anti-Transgender
# 66                 Anti-Other Race/Ethnicity/Ancestry
# 67                     Anti-Multiple Religions, Group
# 68                              Anti-Jehovahs Witness
# 69                                          Anti-Arab

# %%
national_crime_2018_df = sorted_crime_df_N.iloc[70:105, ]
national_crime_2018_df
# Out:
#      value  data_year  month_num  \
# 70     149       2018          0
# 71      94       2018          0
# 72      80       2018          0
# 73      37       2018          0
# 74     130       2018          0
# 75      60       2018          0
# 76       8       2018          0
# 77      51       2018          0
# 78      40       2018          0
# 79      22       2018          0
# 80      20       2018          0
# 81     134       2018          0
# 82     269       2018          0
# 83     183       2018          0
# 84      75       2018          0
# 85      12       2018          0
# 86     741       2018          0
# 87      99       2018          0
# 88     742       2018          0
# 89       4       2018          0
# 90      39       2018          0
# 91     847       2018          0
# 92      24       2018          0
# 93     492       2018          0
# 94     305       2018          0
# 95      34       2018          0
# 96      44       2018          0
# 97       9       2018          0
# 98     191       2018          0
# 99      32       2018          0
# 100     11       2018          0
# 101      8       2018          0
# 102   1942       2018          0
# 103     20       2018          0
# 104    143       2018          0
#
#                                                    key
# 70                                          Anti-Asian
# 71                                 Anti-Other Religion
# 72                                           Anti-Arab
# 73                                Anti-Other Christian
# 74                               Anti-Lesbian (Female)
# 75                            Anti-Physical Disability
# 76                                         Anti-Mormon
# 77                                       Anti-Catholic
# 78                                           Anti-Sikh
# 79                                           Anti-Male
# 80                                       Anti-Bisexual
# 81                          Anti-Multiple Races, Group
# 82                  Anti-Other Race/Ethnicity/Ancestry
# 83               Anti-American Indian or Alaska Native
# 84                                       Multiple Bias
# 85                                          Anti-Hindu
# 86                                     Anti-Gay (Male)
# 87                              Anti-Mental Disability
# 88                                          Anti-White
# 89                            Anti-Atheism/Agnosticism
# 90                                         Anti-Female
# 91                                         Anti-Jewish
# 92                          Anti-Gender Non-Conforming
# 93                             Anti-Hispanic or Latino
# 94   Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 95                                     Anti-Protestant
# 96                      Anti-Multiple Religions, Group
# 97                               Anti-Jehovahs Witness
# 98                               Anti-Islamic (Muslim)
# 99       Anti-Eastern Orthodox (Russian, Greek, Other)
# 100     Anti-Native Hawaiian or Other Pacific Islander
# 101                                      Anti-Buddhist
# 102                     Anti-Black or African American
# 103                                  Anti-Heterosexual
# 104                                   Anti-Transgender

# %% [markdown]
# # 1) Hypothesis: Rise in Anti-Asian Hate Crimes-2018, 2019, 2020

# %%
#2018 Anti Asian 149
#2019 Anti Asian 161
#2020 Anti Asian 279

Anti_Asian_2018 = national_crime_2018_df.iloc[0:1, ]
#Anti_Asian_2018.reset_index(drop=True, inplace=True)
#Anti_Asian_2018.reset_index(level=0, inplace=True)


Anti_Asian_2019 = national_crime_2019_df.iloc[28:29, ]
#Anti_Asian_2019.reset_index(drop=True, inplace=True)
#Anti_Asian_2019.reset_index(level=0, inplace=True)


Anti_Asian_2020 = national_crime_2020_df.iloc[1:2, ]
#Anti_Asian_2020.reset_index(drop=True, inplace=True)
#Anti_Asian_2020.reset_index(level=0, inplace=True)



vertical_2018_2019 = pd.concat([Anti_Asian_2018, Anti_Asian_2019], axis=0)



vertical_2018_2019_2020 = pd.concat([vertical_2018_2019, Anti_Asian_2020], axis=0)
vertical_2018_2019_2020.reset_index(drop=True, inplace=True)
vertical_2018_2019_2020

#Anti_Asian_2018_2019 = pd.merge(Anti_Asian_2018, Anti_Asian_2019, on= "index")
#Anti_Asian_2018_2019


#Statistics:
    #AVG/ mean ---central tendency
    #Medium

#Line graph
# Out:
#    value  data_year  month_num         key
# 0    149       2018          0  Anti-Asian
# 1    161       2019          0  Anti-Asian
# 2    279       2020          0  Anti-Asian

# %%
#AVG 
#This is the average count of hate crimes against Asians over 3 year period (2018-2020)
vertical_2018_2019_2020[["value"]].mean()
# Out:
# value    196.333333
# dtype: float64

# %%
#Medium
vertical_2018_2019_2020[["value"]].median()
# Out:
# value    161.0
# dtype: float64

# %%
#Standard deviation
statistics.pstdev(vertical_2018_2019_2020['value'])
# Out:
# 58.6590904198905

# %%
x_values = [2018, 2019, 2020]

fig, ax = plt.subplots() #fig: container, #ax:part of the pg that you portray data on

ax.plot(vertical_2018_2019_2020['data_year'], vertical_2018_2019_2020['value'], marker = "o", linestyle='--', color= 'blue')

# Set the x-axis label
ax.set_xlabel('Years')

plt.xticks(x_values)

# Set the y-axis label 
ax.set_ylabel('Count of Crimes')

# Set the title
ax.set_title("Anti-Asian Hate Crime 2018-2020")

#plt.savefig("City Latitude vs. Max Temperature.png")

plt.show()

# %% [markdown]
# # Rise in Hate Crimes Post 9/11

# %%
national_crime_1999_df = sorted_crime_df_N[sorted_crime_df_N["data_year"] == 1999]
national_crime_1999_df
# Out:
#      value  data_year  month_num  \
# 735    152       1999          0
# 736      0       1999          0
# 737    303       1999          0
# 738    340       1999          0
# 739      0       1999          0
# 740      8       1999          0
# 741   1112       1999          0
# 742     14       1999          0
# 743      0       1999          0
# 744      0       1999          0
# 745      0       1999          0
# 746      0       1999          0
# 747      6       1999          0
# 748   2983       1999          0
# 749     32       1999          0
# 750     49       1999          0
# 751    476       1999          0
# 752      0       1999          0
# 753      0       1999          0
# 754      0       1999          0
# 755      0       1999          0
# 756    214       1999          0
# 757     32       1999          0
# 758      0       1999          0
# 759     24       1999          0
# 760      0       1999          0
# 761    922       1999          0
# 762     36       1999          0
# 763    186       1999          0
# 764     23       1999          0
# 765    787       1999          0
# 766     50       1999          0
# 767      4       1999          0
# 768      9       1999          0
# 769    178       1999          0
#
#                                                    key
# 735                                Anti-Other Religion
# 736                                         Anti-Hindu
# 737                                         Anti-Asian
# 738                 Anti-Other Race/Ethnicity/Ancestry
# 739      Anti-Eastern Orthodox (Russian, Greek, Other)
# 740                           Anti-Physical Disability
# 741                                        Anti-Jewish
# 742                                  Anti-Heterosexual
# 743                                        Anti-Female
# 744                         Anti-Gender Non-Conforming
# 745                                          Anti-Sikh
# 746                              Anti-Jehovahs Witness
# 747                                      Multiple Bias
# 748                     Anti-Black or African American
# 749                              Anti-Islamic (Muslim)
# 750              Anti-American Indian or Alaska Native
# 751                            Anti-Hispanic or Latino
# 752                                        Anti-Mormon
# 753     Anti-Native Hawaiian or Other Pacific Islander
# 754                                      Anti-Buddhist
# 755                                   Anti-Transgender
# 756                         Anti-Multiple Races, Group
# 757                     Anti-Multiple Religions, Group
# 758                               Anti-Other Christian
# 759                                          Anti-Arab
# 760                                          Anti-Male
# 761                                    Anti-Gay (Male)
# 762                                      Anti-Catholic
# 763                              Anti-Lesbian (Female)
# 764                                      Anti-Bisexual
# 765                                         Anti-White
# 766                                    Anti-Protestant
# 767                           Anti-Atheism/Agnosticism
# 768                             Anti-Mental Disability
# 769  Anti-Lesbian, Gay, Bisexual, or Transgender (M...

# %%
#pull data from 2000; pull data from 2002


sorted_crime_df_N.reset_index(drop=True, inplace=True)
sorted_crime_df_N

national_crime_2000_df = sorted_crime_df_N[sorted_crime_df_N["data_year"] == 2000]
national_crime_2000_df
#national_crime_2000_df = sorted_crime_df_N.iloc[35:70, ]
#national_crime_2000_df
# Out:
#      value  data_year  month_num  \
# 700     38       2000          0
# 701      0       2000          0
# 702     56       2000          0
# 703   2936       2000          0
# 704      0       2000          0
# 705    187       2000          0
# 706      0       2000          0
# 707    280       2000          0
# 708     20       2000          0
# 709     29       2000          0
# 710      0       2000          0
# 711      0       2000          0
# 712      4       2000          0
# 713     21       2000          0
# 714    246       2000          0
# 715     26       2000          0
# 716     58       2000          0
# 717      0       2000          0
# 718      6       2000          0
# 719    174       2000          0
# 720    571       2000          0
# 721      0       2000          0
# 722     18       2000          0
# 723    317       2000          0
# 724    905       2000          0
# 725     49       2000          0
# 726   1121       2000          0
# 727      0       2000          0
# 728     59       2000          0
# 729    904       2000          0
# 730      0       2000          0
# 731      0       2000          0
# 732      0       2000          0
# 733    192       2000          0
# 734      0       2000          0
#
#                                                    key
# 700                                          Anti-Arab
# 701                                   Anti-Transgender
# 702                                      Anti-Catholic
# 703                     Anti-Black or African American
# 704                                        Anti-Mormon
# 705  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 706      Anti-Eastern Orthodox (Russian, Greek, Other)
# 707                                         Anti-Asian
# 708                           Anti-Physical Disability
# 709                              Anti-Islamic (Muslim)
# 710                                          Anti-Sikh
# 711                                         Anti-Hindu
# 712                           Anti-Atheism/Agnosticism
# 713                                      Anti-Bisexual
# 714                         Anti-Multiple Races, Group
# 715                                  Anti-Heterosexual
# 716              Anti-American Indian or Alaska Native
# 717     Anti-Native Hawaiian or Other Pacific Islander
# 718                                      Multiple Bias
# 719                                Anti-Other Religion
# 720                            Anti-Hispanic or Latino
# 721                                        Anti-Female
# 722                             Anti-Mental Disability
# 723                 Anti-Other Race/Ethnicity/Ancestry
# 724                                    Anti-Gay (Male)
# 725                     Anti-Multiple Religions, Group
# 726                                        Anti-Jewish
# 727                         Anti-Gender Non-Conforming
# 728                                    Anti-Protestant
# 729                                         Anti-White
# 730                              Anti-Jehovahs Witness
# 731                                      Anti-Buddhist
# 732                                          Anti-Male
# 733                              Anti-Lesbian (Female)
# 734                               Anti-Other Christian

# %%
national_crime_2001_df = sorted_crime_df_N[sorted_crime_df_N["data_year"] == 2001]
national_crime_2001_df
# Out:
#      value  data_year  month_num  \
# 665    254       2001          0
# 666      5       2001          0
# 667    187       2001          0
# 668      0       2001          0
# 669    499       2001          0
# 670     15       2001          0
# 671      8       2001          0
# 672   1251       2001          0
# 673    205       2001          0
# 674     36       2001          0
# 675     14       2001          0
# 676      0       2001          0
# 677    818       2001          0
# 678    991       2001          0
# 679      0       2001          0
# 680      0       2001          0
# 681    280       2001          0
# 682      0       2001          0
# 683    605       2001          0
# 684      0       2001          0
# 685      0       2001          0
# 686     78       2001          0
# 687    177       2001          0
# 688      0       2001          0
# 689    218       2001          0
# 690   1051       2001          0
# 691     23       2001          0
# 692   2920       2001          0
# 693     15       2001          0
# 694      0       2001          0
# 695      0       2001          0
# 696     46       2001          0
# 697     34       2001          0
# 698      0       2001          0
# 699      0       2001          0
#
#                                                    key
# 665                                          Anti-Arab
# 666                           Anti-Atheism/Agnosticism
# 667                                Anti-Other Religion
# 668                                        Anti-Mormon
# 669                              Anti-Islamic (Muslim)
# 670                                  Anti-Heterosexual
# 671                                      Multiple Bias
# 672                 Anti-Other Race/Ethnicity/Ancestry
# 673                              Anti-Lesbian (Female)
# 674                                      Anti-Catholic
# 675                           Anti-Physical Disability
# 676                         Anti-Gender Non-Conforming
# 677                                         Anti-White
# 678                                    Anti-Gay (Male)
# 679                                         Anti-Hindu
# 680                               Anti-Other Christian
# 681                                         Anti-Asian
# 682                                          Anti-Sikh
# 683                            Anti-Hispanic or Latino
# 684                              Anti-Jehovahs Witness
# 685                                          Anti-Male
# 686              Anti-American Indian or Alaska Native
# 687  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 688                                   Anti-Transgender
# 689                         Anti-Multiple Races, Group
# 690                                        Anti-Jewish
# 691                             Anti-Mental Disability
# 692                     Anti-Black or African American
# 693                                      Anti-Bisexual
# 694                                      Anti-Buddhist
# 695     Anti-Native Hawaiian or Other Pacific Islander
# 696                     Anti-Multiple Religions, Group
# 697                                    Anti-Protestant
# 698                                        Anti-Female
# 699      Anti-Eastern Orthodox (Russian, Greek, Other)

# %%
#1999 Anti-Muslim 32
#2000 Anti-Muslim 29
#2001 Anti-Muslim 499

    

Anti_Muslim_1999 = national_crime_1999_df.iloc[14:15, ]



Anti_Muslim_2000 = national_crime_2000_df.iloc[9:10, ]



Anti_Muslim_2001 = national_crime_2001_df.iloc[4:5, ]




Anti_Muslim_1999_2000 = pd.concat([Anti_Muslim_1999, Anti_Muslim_2000], axis=0)



Anti_Muslim_1999_2000_2001 = pd.concat([Anti_Muslim_1999_2000, Anti_Muslim_2001], axis=0)
Anti_Muslim_1999_2000_2001.reset_index(drop=True, inplace=True)
Anti_Muslim_1999_2000_2001
# Out:
#    value  data_year  month_num                    key
# 0     32       1999          0  Anti-Islamic (Muslim)
# 1     29       2000          0  Anti-Islamic (Muslim)
# 2    499       2001          0  Anti-Islamic (Muslim)

# %%
#1999 Anti-Arab 24
#2000 Anti-Arab 38
#2001 Anti-Arab 254

Anti_Arab_1999 = national_crime_1999_df.iloc[24:25, ]



Anti_Arab_2000 = national_crime_2000_df.iloc[0:1, ]



Anti_Arab_2001 = national_crime_2001_df.iloc[0:1, ]




Anti_Arab_1999_2000 = pd.concat([Anti_Arab_1999, Anti_Arab_2000], axis=0)



Anti_Arab_1999_2000_2001 = pd.concat([Anti_Arab_1999_2000, Anti_Arab_2001], axis=0)
Anti_Arab_1999_2000_2001.reset_index(drop=True, inplace=True)
Anti_Arab_1999_2000_2001
# Out:
#    value  data_year  month_num        key
# 0     24       1999          0  Anti-Arab
# 1     38       2000          0  Anti-Arab
# 2    254       2001          0  Anti-Arab

# %%
x_values_MA = [1999, 2000, 2001]

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots(figsize=(10, 10))

# Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
ax.plot(Anti_Muslim_1999_2000_2001["data_year"], Anti_Muslim_1999_2000_2001["value"],
        marker = "o", linestyle='--', color= 'red')

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(Anti_Arab_1999_2000_2001["data_year"], Anti_Arab_1999_2000_2001["value"], 
        marker = "o", linestyle='--', color= 'blue')

# Customize the x-axis label
ax.set_xlabel("Year", fontsize = 20)
plt.xticks(x_values_MA)

# Customize the y-axis label
ax.set_ylabel("Count of Crimes", fontsize = 20)

# Add the title
ax.set_title("Anti-Muslim & Anti-Arab Hate Crime 1999-2001", fontsize = 25)

plt.text(1999, 50 ,'24', fontdict=None, fontsize = 14, fontweight ='bold', color ='blue')
plt.text(1999.90, 50,'38', fontdict=None, fontsize = 14, fontweight ='bold', color ='blue')
plt.text(2000.95, 270 ,'254', fontdict=None, fontsize = 14, fontweight ='bold', color ='blue')

plt.text(1999, 70 ,'32', fontdict=None, fontsize = 14, fontweight ='bold', color ='red')
plt.text(1999.90, 70,'29', fontdict=None, fontsize = 14, fontweight ='bold', color ='red')
plt.text(2000.95, 510 ,'499', fontdict=None, fontsize = 14, fontweight ='bold', color ='red')

# Call the show function
plt.show()

# %%
sorted_crime_df_N.reset_index(drop=True, inplace=True)
sorted_crime_df_N

Anti_Black_df = sorted_crime_df_N[sorted_crime_df_N["key"] == 'Anti-Black or African American']
Anti_Black_df
# Out:
#       value  data_year  month_num                             key
# 21     2871       2020          0  Anti-Black or African American
# 50     1972       2019          0  Anti-Black or African American
# 102    1942       2018          0  Anti-Black or African American
# 106    2059       2017          0  Anti-Black or African American
# 154    1771       2016          0  Anti-Black or African American
# 176    1756       2015          0  Anti-Black or African American
# 241    1647       2014          0  Anti-Black or African American
# 267    1908       2013          0  Anti-Black or African American
# 285    2059       2012          0  Anti-Black or African American
# 340    2099       2011          0  Anti-Black or African American
# 356    2202       2010          0  Anti-Black or African American
# 394    2297       2009          0  Anti-Black or African American
# 439    2951       2008          0  Anti-Black or African American
# 474    2671       2007          0  Anti-Black or African American
# 514    2631       2006          0  Anti-Black or African American
# 534    2669       2005          0  Anti-Black or African American
# 563    2757       2004          0  Anti-Black or African American
# 627    2572       2003          0  Anti-Black or African American
# 643    2506       2002          0  Anti-Black or African American
# 692    2920       2001          0  Anti-Black or African American
# 703    2936       2000          0  Anti-Black or African American
# 748    2983       1999          0  Anti-Black or African American
# 780    2960       1998          0  Anti-Black or African American
# 827    3141       1997          0  Anti-Black or African American
# 874    3670       1996          0  Anti-Black or African American
# 889    2989       1995          0  Anti-Black or African American
# 917    2178       1994          0  Anti-Black or African American
# 971    2821       1993          0  Anti-Black or African American
# 1007   2311       1992          0  Anti-Black or African American
# 1040   1624       1991          0  Anti-Black or African American

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots(figsize=(10, 10))

# Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
ax.plot(Anti_Black_df["data_year"], Anti_Black_df["value"],
        marker = "o", linestyle='--', color= 'red')


# Customize the x-axis label
ax.set_xlabel("Year", fontsize = 20)

# Customize the y-axis label
ax.set_ylabel("Count of Crimes", fontsize = 20)

# Add the title
ax.set_title("Anti-Black Hate Crime 30 Years", fontsize = 25)


# Call the show function
plt.show()

#“We black men have a hard enough time in our own struggle for justice. 
#The only people in this country who are asked to be nonviolent are black people.”

#"Before George Floyd, Breonna Taylor and Ahmaud Arbery, there were many more. 
#Black people have been calling out in pain and calling for help for a very long time.”
